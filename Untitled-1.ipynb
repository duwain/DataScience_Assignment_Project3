# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install --upgrade 'sqlalchemy<2.0'
# Out:
# The system cannot find the file specified.

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
import pymysql
pymysql.install_as_MySQLdb()
import pandas as pd

# %% [markdown]
# # ![title](sakila-db-model.png)

# %%
from sqlalchemy import create_engine
# Create connection string using credentials following this format
# connection = "dialect+driver://username:password@host:port/database"
username = "root"
password = "root" # (or whatever password you chose during mysql installation)
db_name = "sakila"
connection = f"mysql+pymysql://{username}:{password}@localhost/{db_name}"

# %%
engine = create_engine(connection)

# %%
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost/sakila)

# %%
q = """SELECT * FROM customer;"""
pd.read_sql(q, engine)
# Out:
#      customer_id  store_id first_name  last_name  \
# 0              1         1       MARY      SMITH
# 1              2         1   PATRICIA    JOHNSON
# 2              3         1      LINDA   WILLIAMS
# 3              4         2    BARBARA      JONES
# 4              5         1  ELIZABETH      BROWN
# ..           ...       ...        ...        ...
# 594          595         1   TERRENCE  GUNDERSON
# 595          596         1    ENRIQUE   FORSYTHE
# 596          597         1    FREDDIE     DUGGAN
# 597          598         1       WADE   DELVALLE
# 598          599         2     AUSTIN    CINTRON
#
#                                      email  address_id  active  \
# 0            MARY.SMITH@sakilacustomer.org           5       1
# 1      PATRICIA.JOHNSON@sakilacustomer.org           6       1
# 2        LINDA.WILLIAMS@sakilacustomer.org           7       1
# 3         BARBARA.JONES@sakilacustomer.org           8       1
# ...

# %%
query = """
SELECT address.city_id AS city_id, customer.first_name AS first_name, customer.last_name AS last_name, customer.email, address.address
FROM customer
JOIN address ON customer.address_id = address.address_id
WHERE address.city_id = 312;
"""
pd.read_sql(query, engine)
# Out:
#    city_id first_name last_name                              email  \
# 0      312     MATTIE   HOFFMAN  MATTIE.HOFFMAN@sakilacustomer.org
# 1      312      CECIL     VINES     CECIL.VINES@sakilacustomer.org
#
#               address
# 0   1497 Yuzhou Drive
# 1  548 Uruapan Street

# %%
query = """
    SELECT * FROM film
    JOIN film_category ON film.film_id = film_category.film_id
    JOIN category ON film_category.category_id = category.category_id
    WHERE category.name = 'Comedy';
    """
pd.read_sql(query, engine)
# Out:
#     film_id                    title  \
# 0         7          AIRPLANE SIERRA
# 1        28              ANTHEM LUKE
# 2        99      BRINGING HYSTERICAL
# 3       119            CAPER MOTIONS
# 4       127            CAT CONEHEADS
# 5       159              CLOSER BANG
# 6       178   CONNECTION MICROCOSMOS
# 7       182           CONTROL ANTHEM
# 8       188               CRAZY HOME
# 9       202         DADDY PITTSBURGH
# 10      242             DOOM DANCING
# 11      247          DOWNHILL ENOUGH
# 12      265              DYING MAKER
# 13      276           ELEMENT FREDDY
# 14      308            FERRIS MOTHER
# 15      317    FIREBALL PHILADELPHIA
# 16      324    FLINTSTONES HAPPINESS
# 17      332    FRANKENSTEIN STRANGER
# 18      335        FREEDOM CLEOPATRA
# 19      365               GOLD RIVER
# 20      385          GROUNDHOG UNCUT
# 21      388            GUNFIGHT MOON
# 22      404            HATE HANDICAP
# 23      410           HEAVEN FREEDOM
# ...

# %%
query = """
SELECT actor.last_name AS last_name , film.title, film.release_year
FROM film
JOIN actor ON actor.actor_id = actor.actor_id
WHERE actor.last_name = 'Lollobrigida';
"""
pd.read_sql(query, engine)
# Out:
#         last_name              title  release_year
# 0    LOLLOBRIGIDA   ACADEMY DINOSAUR          2006
# 1    LOLLOBRIGIDA     ACE GOLDFINGER          2006
# 2    LOLLOBRIGIDA   ADAPTATION HOLES          2006
# 3    LOLLOBRIGIDA   AFFAIR PREJUDICE          2006
# 4    LOLLOBRIGIDA        AFRICAN EGG          2006
# ..            ...                ...           ...
# 995  LOLLOBRIGIDA     YOUNG LANGUAGE          2006
# 996  LOLLOBRIGIDA         YOUTH KICK          2006
# 997  LOLLOBRIGIDA       ZHIVAGO CORE          2006
# 998  LOLLOBRIGIDA  ZOOLANDER FICTION          2006
# 999  LOLLOBRIGIDA          ZORRO ARK          2006
#
# [1000 rows x 3 columns]

# %%
query=""" 
SELECT film.title, actor.first_name, actor.last_name
FROM film
JOIN actor ON actor.actor_id = actor.actor_id
WHERE film.title ='Bingo Talented';
"""
pd.read_sql(query, engine)
# Out:
#               title first_name     last_name
# 0    BINGO TALENTED   PENELOPE       GUINESS
# 1    BINGO TALENTED       NICK      WAHLBERG
# 2    BINGO TALENTED         ED         CHASE
# 3    BINGO TALENTED   JENNIFER         DAVIS
# 4    BINGO TALENTED     JOHNNY  LOLLOBRIGIDA
# ..              ...        ...           ...
# 195  BINGO TALENTED       BELA        WALKEN
# 196  BINGO TALENTED      REESE          WEST
# 197  BINGO TALENTED       MARY        KEITEL
# 198  BINGO TALENTED      JULIA       FAWCETT
# 199  BINGO TALENTED      THORA        TEMPLE
#
# [200 rows x 3 columns]

# %%
query= """
SELECT customer_id, amount
FROM payment
WHERE amount > 2 * (SELECT AVG(amount) FROM payment);
"""
pd.read_sql(query, engine)
# Out:
#      customer_id  amount
# 0              1    9.99
# 1              2   10.99
# 2              3    8.99
# 3              3   10.99
# 4              3    8.99
# ..           ...     ...
# 852          595    9.99
# 853          595   10.99
# 854          597    8.99
# 855          599    9.99
# 856          599    8.99
#
# [857 rows x 2 columns]

# %%
query="""
SELECT c.first_name, c.last_name, COUNT(p.customer_id) AS num_payments
FROM customer AS c
JOIN payment AS p ON c.customer_id = p.customer_id
GROUP BY c.customer_id
ORDER BY num_payments DESC
LIMIT 5;
"""
pd.read_sql(query, engine)
# Out:
#   first_name last_name  num_payments
# 0    ELEANOR      HUNT            46
# 1       KARL      SEAL            45
# 2     MARCIA      DEAN            42
# 3      CLARA      SHAW            42
# 4      TAMMY   SANDERS            41
